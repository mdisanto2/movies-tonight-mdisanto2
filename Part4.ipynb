# %% [markdown]
# # Movies Tonight Part 4: A few SELECT queries
# __Use `%%sql` magic to write the queries listed below.__

# %%
# load %sql magic extension
# %load_ext sql

# initialize a database connection; may have to adjust username and password 
# %sql sqlite:///Movies.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: @Movies.db'

# %% [markdown]
# **1. Write a select query that returns the MovieTitle, TheaterName, and Showtime for each movie showing.**
# The query should use `JOIN` syntax as described in your textbook. Also, use aliases ( `… AS …` ) to make sure that column names match exactly what is asked for.

# %%
# %%sql
# SELECT MOVIES.TITLE as MovieTitle, THEATERS.NAME as TheaterName, SHOWS.SHOWTIME as Showtime
# FROM SHOWS
# JOIN THEATERS USING (TID)
# JOIN MOVIES USING (MID);
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '4:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '7:20 PM'),
#  ('Associate, The', 'Akarakian Theatres Moreno 4 Cinemas', '9:40 PM'),
#  ('Ghost & The Darkness, The', 'Akarakian Theatres Moreno 4 Cinemas', '5:10 PM'),
#  ('Ghost & The Darkness, The', 'Akarakian Theatres Moreno 4 Cinemas', '9:00 PM'),
#  ('Ghost & The Darkness, The', 'Akarakian Theatres Moreno 4 Cinemas', '9:05 PM'),
#  ('Independence Day', 'Akarakian Theatres Moreno 4 Cinemas', '7:00 PM'),
#  ('Associate, The', 'Cinema Star The Ultraplex 14', '4:40 PM'),
#  ('Associate, The', 'Cinema Star The Ultraplex 14', '7:30 PM'),
#  ('D3: The Mighty Ducks', 'Cinema Star The Ultraplex 14', '2:30 PM'),
#  ('Dear God', 'Cinema Star The Ultraplex 14', '5:15 PM'),
#  ('Dear God', 'Cinema Star The Ultraplex 14', '7:45 PM'),
#  ('First Wives Club, The', 'Cinema Star The Ultraplex 14', '5:30 PM'),
#  ('First Wives Club, The', 'Cinema Star The Ultraplex 14', '8:00 PM'),
#  ('Ghost & The Darkness, The', 'Cinema Star The Ultraplex 14', '5:00 PM'),
#  ('Ghost & The Darkness, The', 'Cinema Star The Ultraplex 14', '7:40 PM'),
#  ('High School High', 'Cinema Star The Ultraplex 14', '4:00 PM'),
#  ('High School High', 'Cinema Star The Ultraplex 14', '6:15 PM'),
#  ('High School High', 'Cinema Star The Ultraplex 14', '8:30 PM'),
#  ('Larger Than Life', 'Cinema Star The Ultraplex 14', '8:20 PM'),
#  ('Mirror Has Two Faces, The', 'Cinema Star The Ultraplex 14', '4:45 PM'),
#  ('Mirror Has Two Faces, The', 'Cinema Star The Ultraplex 14', '5:45 PM'),
#  ('Mirror Has Two Faces, The', 'Cinema Star The Ultraplex 14', '7:45 PM'),
#  ('Mirror Has Two Faces, The', 'Cinema Star The Ultraplex 14', '8:45 PM'),
#  ('Ransom', 'Cinema Star The Ultraplex 14', '4:15 PM'),
#  ('Ransom', 'Cinema Star The Ultraplex 14', '4:45 PM'),
#  ('Ransom', 'Cinema Star The Ultraplex 14', '5:15 PM'),
#  ('Ransom', 'Cinema Star The Ultraplex 14', '7:00 PM'),
#  ('Ransom', 'Cinema Star The Ultraplex 14', '7:30 PM'),
#  ('Ransom', 'Cinema Star The Ultraplex 14', '8:00 PM'),
#  ('Ransom', 'Cinema Star The Ultraplex 14', '9:45 PM'),
#  ('Sleepers', 'Cinema Star The Ultraplex 14', '7:30 PM'),
#  ('Space Jam', 'Cinema Star The Ultraplex 14', '5:00 PM'),
#  ('Space Jam', 'Cinema Star The Ultraplex 14', '6:00 PM'),
#  ('Space Jam', 'Cinema Star The Ultraplex 14', '7:15 PM'),
#  ('Space Jam', 'Cinema Star The Ultraplex 14', '8:15 PM'),
#  ("Stephen King's Thinner", 'Cinema Star The Ultraplex 14', '6:00 PM'),
#  ('Associate, The', 'General Cinema Rancho 6', '5:00 PM'),
#  ('Associate, The', 'General Cinema Rancho 6', '7:30 PM'),
#  ('Dear God', 'General Cinema Rancho 6', '4:45 PM'),
#  ('Dear God', 'General Cinema Rancho 6', '7:15 PM'),
#  ('First Wives Club, The', 'General Cinema Rancho 6', '5:30 PM'),
#  ('First Wives Club, The', 'General Cinema Rancho 6', '8:00 PM'),
#  ('Michael Collins', 'General Cinema Rancho 6', '4:00 PM'),
#  ('Michael Collins', 'General Cinema Rancho 6', '7:15 PM'),
#  ('Romeo & Juliet', 'General Cinema Rancho 6', '5:15 PM'),
#  ('Romeo & Juliet', 'General Cinema Rancho 6', '7:45 PM'),
#  ('Sleepers', 'General Cinema Rancho 6', '7:00 PM'),
#  ('Ghost & The Darkness, The', 'Pacific Inland Center', '10:05 PM'),
#  ('Ghost & The Darkness, The', 'Pacific Inland Center', '5:15 PM'),
#  ('Ghost & The Darkness, The', 'Pacific Inland Center', '7:40 PM'),
#  ('Big Night', 'SOCAL Canyon Crest Cinema', '4:40 PM'),
#  ('Big Night', 'SOCAL Canyon Crest Cinema', '7:10 PM'),
#  ('Big Night', 'SOCAL Canyon Crest Cinema', '9:40 PM'),
#  ('Fly Away Home', 'SOCAL Canyon Crest Cinema', '3:50 PM'),
#  ('Ghost & The Darkness, The', 'SOCAL Canyon Crest Cinema', '6:50 PM'),
#  ('Ghost & The Darkness, The', 'SOCAL Canyon Crest Cinema', '9:15 PM'),
#  ('Independence Day', 'SOCAL Canyon Crest Cinema', '6:10 PM'),
#  ('Independence Day', 'SOCAL Canyon Crest Cinema', '9:10 PM'),
#  ('Michael Collins', 'SOCAL Canyon Crest Cinema', '6:20 PM'),
#  ('Michael Collins', 'SOCAL Canyon Crest Cinema', '9:10 PM'),
#  ('Nutty Professor, The', 'SOCAL Canyon Crest Cinema', '4:25 PM'),
#  ('Nutty Professor, The', 'SOCAL Canyon Crest Cinema', '8:05 PM'),
#  ('Phenomenon', 'SOCAL Canyon Crest Cinema', '6:20 PM'),
#  ('Phenomenon', 'SOCAL Canyon Crest Cinema', '9:15 PM'),
#  ('Romeo & Juliet', 'SOCAL Canyon Crest Cinema', '4:30 PM'),
#  ('Romeo & Juliet', 'SOCAL Canyon Crest Cinema', '7:00 PM'),
#  ('Romeo & Juliet', 'SOCAL Canyon Crest Cinema', '9:30 PM'),
#  ('Set It Off', 'SOCAL Canyon Crest Cinema', '4:10 PM'),
#  ('Set It Off', 'SOCAL Canyon Crest Cinema', '6:30 PM'),
#  ('Set It Off', 'SOCAL Canyon Crest Cinema', '9:00 PM'),
#  ('Surviving Picasso', 'SOCAL Canyon Crest Cinema', '6:40 PM'),
#  ('Surviving Picasso', 'SOCAL Canyon Crest Cinema', '9:25 PM'),
#  ('Very Brady Sequel, A', 'SOCAL Canyon Crest Cinema', '6:00 PM'),
#  ('D3: The Mighty Ducks', 'SOCAL Canyon Springs Cinema', '4:15 PM'),
#  ('Dear God', 'SOCAL Canyon Springs Cinema', '6:40 PM'),
#  ('Dear God', 'SOCAL Canyon Springs Cinema', '9:00 PM'),
#  ('First Wives Club, The', 'SOCAL Canyon Springs Cinema', '4:20 PM'),
#  ('First Wives Club, The', 'SOCAL Canyon Springs Cinema', '6:30 PM'),
#  ('First Wives Club, The', 'SOCAL Canyon Springs Cinema', '8:40 PM'),
#  ('Fly Away Home', 'SOCAL Canyon Springs Cinema', '4:50 PM'),
#  ('Ghost & The Darkness, The', 'SOCAL Canyon Springs Cinema', '7:20 PM'),
#  ('Ghost & The Darkness, The', 'SOCAL Canyon Springs Cinema', '9:50 PM'),
#  ('Romeo & Juliet', 'SOCAL Canyon Springs Cinema', '4:30 PM'),
#  ('Romeo & Juliet', 'SOCAL Canyon Springs Cinema', '7:00 PM'),
#  ('Romeo & Juliet', 'SOCAL Canyon Springs Cinema', '9:30 PM'),
#  ('Set It Off', 'SOCAL Canyon Springs Cinema', '4:25 PM'),
#  ('Set It Off', 'SOCAL Canyon Springs Cinema', '6:50 PM'),
#  ('Set It Off', 'SOCAL Canyon Springs Cinema', '9:15 PM'),
#  ('Sleepers', 'SOCAL Canyon Springs Cinema', '5:30 PM'),
#  ('Sleepers', 'SOCAL Canyon Springs Cinema', '8:30 PM'),
#  ('That Thing You Do', 'SOCAL Canyon Springs Cinema', '4:40 PM'),
#  ('That Thing You Do', 'SOCAL Canyon Springs Cinema', '7:15 PM'),
#  ('That Thing You Do', 'SOCAL Canyon Springs Cinema', '9:40 PM'),
#  ('Mirror Has Two Faces, The', 'SOCAL Marketplace Cinema', '4:10 PM'),
#  ('Mirror Has Two Faces, The', 'SOCAL Marketplace Cinema', '6:45 PM'),
#  ('Mirror Has Two Faces, The', 'SOCAL Marketplace Cinema', '9:25 PM'),
#  ('Ransom', 'SOCAL Marketplace Cinema', '4:20 PM'),
#  ('Ransom', 'SOCAL Marketplace Cinema', '5:20 PM'),
#  ('Ransom', 'SOCAL Marketplace Cinema', '7:00 PM'),
#  ('Ransom', 'SOCAL Marketplace Cinema', '8:00 PM'),
#  ('Ransom', 'SOCAL Marketplace Cinema', '9:40 PM'),
#  ('Space Jam', 'SOCAL Marketplace Cinema', '4:45 PM'),
#  ('Space Jam', 'SOCAL Marketplace Cinema', '5:50 PM'),
#  ('Space Jam', 'SOCAL Marketplace Cinema', '7:15 PM'),
#  ('Space Jam', 'SOCAL Marketplace Cinema', '8:10 PM'),
#  ('Space Jam', 'SOCAL Marketplace Cinema', '9:30 PM'),
#  ('First Wives Club, The', 'United Artists Riverside (Galleria) Tyler Mall', '4:20 PM'),
#  ('First Wives Club, The', 'United Artists Riverside (Galleria) Tyler Mall', '7:10 PM'),
#  ('First Wives Club, The', 'United Artists Riverside (Galleria) Tyler Mall', '9:30 PM'),
#  ('High School High', 'United Artists Riverside (Galleria) Tyler Mall', '5:00 PM'),
#  ('High School High', 'United Artists Riverside (Galleria) Tyler Mall', '7:00 PM'),
#  ('High School High', 'United Artists Riverside (Galleria) Tyler Mall', '9:00 PM'),
#  ('Romeo & Juliet', 'United Artists Riverside (Galleria) Tyler Mall', '4:30 PM'),
#  ('Romeo & Juliet', 'United Artists Riverside (Galleria) Tyler Mall', '7:00 PM'),
#  ('Romeo & Juliet', 'United Artists Riverside (Galleria) Tyler Mall', '9:45 PM'),
#  ('Space Jam', 'United Artists Riverside (Galleria) Tyler Mall', '5:25 PM'),
#  ('Space Jam', 'United Artists Riverside (Galleria) Tyler Mall', '7:30 PM'),
#  ('Space Jam', 'United Artists Riverside (Galleria) Tyler Mall', '9:35 PM'),
#  ('Dear God', 'United Artists Riverside Park Sierra', '5:15 PM'),
#  ('Dear God', 'United Artists Riverside Park Sierra', '9:25 PM'),
#  ('Ghost & The Darkness, The', 'United Artists Riverside Park Sierra', '7:15 PM'),
#  ('Larger Than Life', 'United Artists Riverside Park Sierra', '7:30 PM'),
#  ('Mirror Has Two Faces, The', 'United Artists Riverside Park Sierra', '10:20 PM'),
#  ('Mirror Has Two Faces, The', 'United Artists Riverside Park Sierra', '4:30 PM'),
#  ('Mirror Has Two Faces, The', 'United Artists Riverside Park Sierra', '7:40 PM'),
#  ('Set It Off', 'United Artists Riverside Park Sierra', '10:05 PM'),
#  ('Set It Off', 'United Artists Riverside Park Sierra', '4:40 PM'),
#  ('Set It Off', 'United Artists Riverside Park Sierra', '7:20 PM'),
#  ('Sleepers', 'United Artists Riverside Park Sierra', '4:20 PM'),
#  ('Sleepers', 'United Artists Riverside Park Sierra', '9:30 PM')]

# %% [markdown]
# **2. Write a select query to display the MovieTitle, TheaterName, and Showtime for each show after 7pm.** You can start with a copy of the previous query and then add a `WHERE` clause.

# %%
# %%sql
# SELECT MOVIES.TITLE as MovieTitle, THEATERS.NAME as TheaterName, SHOWS.SHOWTIME as Showtime
# FROM SHOWS
#     JOIN THEATERS USING (TID)
#     JOIN MOVIES USING (MID)
# WHERE SHOWTIME

# %%
# %%sql
# SELECT strftime('%Y-%m-%dT-%H:%M:%S', 'now') as ptime
# Out:
#  * sqlite:///Movies.db
# Done.
# [('2020-03-05T-01:45:14',)]

# %% [markdown]
# **3. Write a select query to display the cast (actors only) of each movie.** The query should return the Movie Title, Actor Name, MID, and AID.

# %%
# %%sql
# SELECT DISTINCT MOVIES.MID, MOVIES.TITLE, ARTISTS.AID, ARTISTS.NAME
# FROM MOVIES
#     JOIN CREDITS USING (MID)
#     JOIN ARTISTS USING (AID)
# WHERE CREDITS.CCODE = 'A';
# Out:
#  * sqlite:///Movies.db
# Done.
# [(1, 'Associate, The', 1, 'Austin Pendleton'),
#  (1, 'Associate, The', 2, 'Bebe Neuwirth'),
#  (1, 'Associate, The', 3, 'Dianne Wiest'),
#  (1, 'Associate, The', 4, 'Eli Wallach'),
#  (1, 'Associate, The', 5, 'Kenny Kerr'),
#  (1, 'Associate, The', 6, 'Lainie Kazan'),
#  (20, 'Set It Off', 127, 'Blair Underwood'),
#  (20, 'Set It Off', 117, 'Jada Pinkett'),
#  (20, 'Set It Off', 128, 'John C. McGinley'),
#  (20, 'Set It Off', 129, 'Kimberly Elise'),
#  (20, 'Set It Off', 130, 'Queen Latifah'),
#  (20, 'Set It Off', 28, 'Vivica Fox'),
#  (21, 'Surviving Picasso', 132, 'Anthony Hopkins'),
#  (21, 'Surviving Picasso', 100, 'Diane Venora'),
#  (21, 'Surviving Picasso', 133, 'Joan Plowright'),
#  (21, 'Surviving Picasso', 134, 'Julianne Moore'),
#  (21, 'Surviving Picasso', 135, 'Natascha McElhone'),
#  (22, 'Very Brady Sequel, A', 137, 'Christine Taylor'),
#  (22, 'Very Brady Sequel, A', 138, 'Christopher Daniel Barnes'),
#  (22, 'Very Brady Sequel, A', 139, 'Gary Cole'),
#  (22, 'Very Brady Sequel, A', 140, 'Henriette Mantel'),
#  (22, 'Very Brady Sequel, A', 141, 'Jennifer Elise Cox'),
#  (22, 'Very Brady Sequel, A', 142, 'Jesse Lee'),
#  (22, 'Very Brady Sequel, A', 143, 'Olivia Hack'),
#  (22, 'Very Brady Sequel, A', 144, 'Paul Sutera'),
#  (22, 'Very Brady Sequel, A', 145, 'Shelley Long'),
#  (22, 'Very Brady Sequel, A', 146, 'Tim Matheson'),
#  (4, 'D3: The Mighty Ducks', 148, 'Joss AcklandDirected by</B> Rob Lieberma'),
#  (23, 'That Thing You Do', 149, 'Ethan Embry'),
#  (23, 'That Thing You Do', 150, 'Johnathon Schaech'),
#  (23, 'That Thing You Do', 151, 'Steve Zahn'),
#  (23, 'That Thing You Do', 152, 'Tom Everett Scott')]

# %% [markdown]
# **4. Write a select query to display the number of distinct movies that each actor appears in.** The query should return the ActorName, MovieCount, and AID. You will need to use use a GROUP BY clause and the COUNT() function.

# %%
# %%sql
# SELECT ARTISTS.AID, ARTISTS.NAME as ActorName, COUNT(DISTINCT MID) as MovieCount
# FROM MOVIES
#     JOIN CREDITS USING (MID)
#     JOIN ARTISTS USING (AID)
# WHERE CREDITS.CCODE = 'A'
# GROUP BY ARTISTS.AID, ARTISTS.NAME;
# Out:
#  * sqlite:///Movies.db
# Done.
# [(1, 'Austin Pendleton', 1),
#  (2, 'Bebe Neuwirth', 1),
#  (3, 'Dianne Wiest', 1),
#  (4, 'Eli Wallach', 1),
#  (5, 'Kenny Kerr', 1),
#  (6, 'Lainie Kazan', 1),
#  (7, 'Tim Daly', 1),
#  (8, 'Whoopi Goldberg', 1),
#  (10, 'Bernard Hill', 1),
#  (11, 'Brian McCardie', 1),
#  (12, 'Emily Mortimer', 1),
#  (13, 'Henry Cele', 1),
#  (14, 'John Kani', 1),
#  (15, 'Michael Douglas', 1),
#  (16, 'Tom Wilkinson', 1),
#  (17, 'Val Kilmer', 1),
#  (19, 'Bill Pullman', 1),
#  (20, 'Bill Smitrovich', 1),
#  (21, 'Harvey Fierstein', 1),
#  (22, 'Jeff Goldblum', 1),
#  (23, 'Judd Hirsch', 1),
#  (24, 'Margaret Colin', 1),
#  (25, 'Mary McDonnell', 1),
#  (26, 'Randy Quaid', 1),
#  (27, 'Robert Loggia', 1),
#  (28, 'Vivica Fox', 2),
#  (29, 'Will Smith', 1),
#  (31, 'Emilio Estevez', 1),
#  (32, 'Heidi Kling', 1),
#  (33, 'Jeffrey Nordling', 1),
#  (34, 'Joss Ackland', 1),
#  (35, 'Rob Lieberman', 1),
#  (36, 'Greg Kinnear', 1),
#  (37, 'Hector Elizondo', 1),
#  (38, 'Jon Seda', 1),
#  (39, 'Laurie Metcalf', 1),
#  (40, 'Maria Pitillo', 1),
#  (41, 'Roscoe Lee Browne', 1),
#  (42, 'Tim Conway', 1),
#  (44, 'Bette Midler', 1),
#  (45, 'Diane Keaton', 1),
#  (46, 'Goldie Hawn', 1),
#  (48, 'and Louise Fletcher', 1),
#  (49, 'Jon Lovitz', 1),
#  (50, 'Mekhi Phifer', 1),
#  (51, 'Tia Carrera', 1),
#  (53, 'Bill Murray', 2),
#  (54, 'Janeane Garofalo', 1),
#  (55, 'Jeremy Piven', 1),
#  (56, 'Keith David', 1),
#  (57, 'Matthew McConaughey', 1),
#  (58, 'Pat Hingle', 1),
#  (60, 'Barbra Streisand', 1),
#  (61, 'Jeff Bridges', 1),
#  (62, 'Lauren Bacall', 1),
#  (63, 'Pierce Brosnan', 1),
#  (64, 'Delroy Lindo', 1),
#  (65, 'Gary Sinese', 1),
#  (66, 'Lili Taylor', 1),
#  (67, 'Mel Gibson', 1),
#  (68, 'Rene Russo', 1),
#  (70, 'Billy Crudup', 1),
#  (71, 'Brad Pitt', 1),
#  (72, 'Brad Renfro', 1),
#  (73, 'Dustin Hoffman', 1),
#  (74, 'Jason Patric', 1),
#  (75, 'Joseph Perrino', 1),
#  (76, 'Kevin Bacon', 1),
#  (77, 'Minnie Driver', 2),
#  (78, 'Robert De Niro', 1),
#  (79, 'Ron Eldard', 1),
#  (80, 'Terry Kinney', 1),
#  (81, 'Vittorio Gassman', 1),
#  (83, 'Michael Jordan', 1),
#  (84, 'Theresa Randle', 1),
#  (85, 'Wayne Knight', 1),
#  (87, 'Joe Mantegna', 1),
#  (88, 'Kari Wuhrer', 1),
#  (89, 'Lucinda Jenney', 1),
#  (90, 'Michael Constantine', 1),
#  (91, 'Robert John Burke', 1),
#  (93, 'Aidan Quinn', 1),
#  (94, 'Alan Rickman', 1),
#  (95, 'Julia Roberts', 1),
#  (96, 'Liam Neeson', 1),
#  (97, 'Stephen Rea', 1),
#  (99, 'Claire Danes', 1),
#  (100, 'Diane Venora', 2),
#  (101, 'John Leguizamo', 1),
#  (102, 'Leonardo DiCaprio', 1),
#  (103, 'Paul Rudd', 1),
#  (104, 'Paul Sorvino', 1),
#  (106, 'Campbell Scott', 1),
#  (107, 'Ian Holm', 1),
#  (108, 'Isabella Rossellini', 1),
#  (109, 'Stanley Tucci', 1),
#  (110, 'Tony Shalhoub', 1),
#  (111, 'Anna Paquin', 1),
#  (112, 'Dana Delany', 1),
#  (113, 'Jeff Daniels', 1),
#  (115, 'Dave Chappelle', 1),
#  (116, 'Eddie Murphy', 1),
#  (117, 'Jada Pinkett', 2),
#  (118, 'James Coburn', 1),
#  (119, 'John Ales', 1),
#  (120, 'Larry Miller', 1),
#  (122, 'Forest Whitaker', 1),
#  (123, 'John Travolta', 1),
#  (124, 'Kyra Sedgwick', 1),
#  (125, 'Robert Duvall', 1),
#  (127, 'Blair Underwood', 1),
#  (128, 'John C. McGinley', 1),
#  (129, 'Kimberly Elise', 1),
#  (130, 'Queen Latifah', 1),
#  (132, 'Anthony Hopkins', 1),
#  (133, 'Joan Plowright', 1),
#  (134, 'Julianne Moore', 1),
#  (135, 'Natascha McElhone', 1),
#  (137, 'Christine Taylor', 1),
#  (138, 'Christopher Daniel Barnes', 1),
#  (139, 'Gary Cole', 1),
#  (140, 'Henriette Mantel', 1),
#  (141, 'Jennifer Elise Cox', 1),
#  (142, 'Jesse Lee', 1),
#  (143, 'Olivia Hack', 1),
#  (144, 'Paul Sutera', 1),
#  (145, 'Shelley Long', 1),
#  (146, 'Tim Matheson', 1),
#  (148, 'Joss AcklandDirected by</B> Rob Lieberma', 1),
#  (149, 'Ethan Embry', 1),
#  (150, 'Johnathon Schaech', 1),
#  (151, 'Steve Zahn', 1),
#  (152, 'Tom Everett Scott', 1)]

# %% [markdown]
# **5. Write a select query to display only the actors that appear in multiple movies.** The query should return the Actor Name, Movie Count, and AID. You can use the previous select query as a starting point. You will need to add a HAVING clause to do the restriction.

# %%
# %%sql
# SELECT ARTISTS.AID, ARTISTS.NAME as ActorName, COUNT(DISTINCT MID) as MovieCount
# FROM MOVIES
#     JOIN CREDITS USING (MID)
#     JOIN ARTISTS USING (AID)
# WHERE CREDITS.CCODE = 'A'
# GROUP BY ARTISTS.AID, ARTISTS.NAME
# HAVING MovieCount >1;
# Out:
#  * sqlite:///Movies.db
# Done.
# [(28, 'Vivica Fox', 2),
#  (53, 'Bill Murray', 2),
#  (77, 'Minnie Driver', 2),
#  (100, 'Diane Venora', 2),
#  (117, 'Jada Pinkett', 2)]

# %% [markdown]
# **6. Write a select query to display directors that also act in their movies.** The query should return the ArtistName, NumDirectorCredits, NumActorCredits, NumDirectorActorCredits. Each count should be calculated separately using a subquery. Note: NumDirectorActorCredits should be greater than 0.

# %%
# %%sql
# SELECT ARTISTS.NAME as ArtistName, MOVIES.TITLE, COUNT(CCODE) as NumCodes
# FROM ARTISTS
#     JOIN CREDITS USING (AID)
#     JOIN MOVIES USING (MID)
# GROUP BY ARTISTS.AID, MOVIES.MID, ArtistName, MOVIES.TITLE
# HAVING NumCodes > 1;
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Rob Lieberman', 'D3: The Mighty Ducks', 2),
#  ('Barbra Streisand', 'Mirror Has Two Faces, The', 2),
#  ('Campbell Scott', 'Big Night', 2),
#  ('Stanley Tucci', 'Big Night', 2)]

# %%
# %%sql
# SELECT ARTISTS.NAME as ArtistName, MOVIES.TITLE,  c1.CCODE as c1code, c2.CCODE as c2code
# FROM CREDITS as c1
#     JOIN CREDITS as c2 USING (AID, MID)
#     JOIN ARTISTS USING (AID)
#     JOIN MOVIES USING (MID)
# WHERE c1code = 'A' AND c2code = 'D';
# Out:
#  * sqlite:///Movies.db
# Done.
# [('Rob Lieberman', 'D3: The Mighty Ducks', 'A', 'D'),
#  ('Barbra Streisand', 'Mirror Has Two Faces, The', 'A', 'D'),
#  ('Campbell Scott', 'Big Night', 'A', 'D'),
#  ('Stanley Tucci', 'Big Night', 'A', 'D')]
